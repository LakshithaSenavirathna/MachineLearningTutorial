# %% [markdown]
# # 1.Basic Python Syntax for ML

# %% [markdown]
# ## Variables

# %%
print("hello world")
# Out:
# hello world

# %%
a = 10

print(a)
# Out:
# 10

# %%
b = a + 1
print(b)
# Out:
# 11

# %%
name = "USJ"
print(name)
# Out:
# USJ

# %% [markdown]
# ## Lists and Arrays

# %%
x = [1, 2, 3]
print(x)
# Out:
# [1, 2, 3]

# %%
import numpy as np

x = np.array([1, 2, 3])

# %% [markdown]
# ## Function

# %%
def square (x):
  return x * x

# %%
square(5)
# Out:
# 25

# %%
square(3.14)
# Out:
# 9.8596

# %% [markdown]
# ## Importing Packages

# %%
import numpy as np
import pandas as pd
